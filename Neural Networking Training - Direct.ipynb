# %%
# Imports here


import network_helper;
# %matplotlib inline

# %%
train_loader, test_loader = network_helper.load_dataset()

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

classes = list(cat_to_name.values())

# %%
redeNeural = network_helper.create_network(len(classes))

# %%
network_helper.train_network(redeNeural, train_loader, numb_epochs=2);

# %%
redeNeural.load_state_dict(network_helper._reload_module());

# %%
network_helper.valid_network(test_loader, redeNeural, classes);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-45ad829d76a4> in <module>()
# ----> 1 network_helper.valid_network(test_loader, redeNeural, classes);
#
# D:\2018\Machine Learning\Deep Learning with PyTorch [Udacity]\Desafio\pythorch\network_helper.py in valid_network(test_loader, redeNeural, classes, criterion, batch_size)
#     154         loss = criterion(output, target)
#     155         # update test loss
# --> 156         test_loss += loss.item()*data.size(0)
#     157         # convert output probabilities to predicted class
#     158         _, pred = torch.max(output, 1)
#
# KeyboardInterrupt:

# %%
network_helper.show_image_validate(test_loader, redeNeural, classes);
# Out:
# Acertos:  3
